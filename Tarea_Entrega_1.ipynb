# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Remote_Work_and_Mental_Health.csv', index_col=0)
df.head()
# Out:
#              Age      Gender           Job_Role    Industry  \
# Employee_ID
# EMP0001       32  Non-binary                 HR  Healthcare
# EMP0002       40      Female     Data Scientist          IT
# EMP0003       59  Non-binary  Software Engineer   Education
# EMP0004       27        Male  Software Engineer     Finance
# EMP0005       49        Male              Sales  Consulting
#
#              Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# Employee_ID
# EMP0001                       13        Hybrid                     47
# EMP0002                        3        Remote                     52
# EMP0003                       22        Hybrid                     46
# EMP0004                       20        Onsite                     32
# EMP0005                       32        Onsite                     35
#
#              Number_of_Virtual_Meetings  Work_Life_Balance_Rating  \
# Employee_ID
# EMP0001                               7                         2
# EMP0002                               4                         1
# EMP0003                              11                         5
# EMP0004                               8                         4
# EMP0005                              12                         2
#
#             Stress_Level Mental_Health_Condition  \
# Employee_ID
# EMP0001           Medium              Depression
# EMP0002           Medium                 Anxiety
# EMP0003           Medium                 Anxiety
# EMP0004             High              Depression
# EMP0005             High                     NaN
#
#             Access_to_Mental_Health_Resources Productivity_Change  \
# Employee_ID
# EMP0001                                    No            Decrease
# EMP0002                                    No            Increase
# EMP0003                                    No           No Change
# EMP0004                                   Yes            Increase
# EMP0005                                   Yes            Decrease
#
#              Social_Isolation_Rating Satisfaction_with_Remote_Work  \
# Employee_ID
# EMP0001                            1                   Unsatisfied
# EMP0002                            3                     Satisfied
# EMP0003                            4                   Unsatisfied
# EMP0004                            3                   Unsatisfied
# EMP0005                            3                   Unsatisfied
#
#              Company_Support_for_Remote_Work Physical_Activity Sleep_Quality  \
# Employee_ID
# EMP0001                                    1            Weekly          Good
# EMP0002                                    2            Weekly          Good
# EMP0003                                    5               NaN          Poor
# EMP0004                                    3               NaN          Poor
# EMP0005                                    3            Weekly       Average
#
#                     Region
# Employee_ID
# EMP0001             Europe
# EMP0002               Asia
# EMP0003      North America
# EMP0004             Europe
# EMP0005      North America

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5000 entries, EMP0001 to EMP5000
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                5000 non-null   int64
#  1   Gender                             5000 non-null   object
#  2   Job_Role                           5000 non-null   object
#  3   Industry                           5000 non-null   object
#  4   Years_of_Experience                5000 non-null   int64
#  5   Work_Location                      5000 non-null   object
#  6   Hours_Worked_Per_Week              5000 non-null   int64
#  7   Number_of_Virtual_Meetings         5000 non-null   int64
#  8   Work_Life_Balance_Rating           5000 non-null   int64
#  9   Stress_Level                       5000 non-null   object
#  10  Mental_Health_Condition            3804 non-null   object
#  11  Access_to_Mental_Health_Resources  5000 non-null   object
#  12  Productivity_Change                5000 non-null   object
#  13  Social_Isolation_Rating            5000 non-null   int64
#  14  Satisfaction_with_Remote_Work      5000 non-null   object
#  15  Company_Support_for_Remote_Work    5000 non-null   int64
#  16  Physical_Activity                  3371 non-null   object
#  17  Sleep_Quality                      5000 non-null   object
#  18  Region                             5000 non-null   object
# dtypes: int64(7), object(12)
# memory usage: 781.2+ KB

# %%
df['Mental_Health_Condition'].unique()
# Out:
# array(['Depression', 'Anxiety', nan, 'Burnout'], dtype=object)

# %%
df['Physical_Activity'].unique()
# Out:
# array(['Weekly', nan, 'Daily'], dtype=object)

# %%
df['Industry'].unique()
# Out:
# ['Healthcare', 'IT', 'Education', 'Finance', 'Consulting', 'Manufacturing', 'Retail']
# Categories (7, object): ['Consulting', 'Education', 'Finance', 'Healthcare', 'IT', 'Manufacturing',
#                          'Retail']

# %%
df["Mental_Health_Condition"].fillna("None", inplace=True)
# Out:
# /tmp/ipython-input-2861312873.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Mental_Health_Condition"].fillna("None", inplace=True)

# %%
df["Physical_Activity"].fillna("None", inplace=True)
# Out:
# /tmp/ipython-input-1735359258.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Physical_Activity"].fillna("None", inplace=True)

# %%
df['Mental_Health_Condition'] = df['Mental_Health_Condition'].astype('category')
df['Physical_Activity'] = df['Physical_Activity'].astype('category')
df['Industry'] = df['Industry'].astype('category')

# %%
Data_muestra= df.iloc[1000:2000]
#Data_muestra.head()
#Data_muestra.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5000 entries, EMP0001 to EMP5000
# Data columns (total 19 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                5000 non-null   int64
#  1   Gender                             5000 non-null   object
#  2   Job_Role                           5000 non-null   object
#  3   Industry                           5000 non-null   category
#  4   Years_of_Experience                5000 non-null   int64
#  5   Work_Location                      5000 non-null   object
#  6   Hours_Worked_Per_Week              5000 non-null   int64
#  7   Number_of_Virtual_Meetings         5000 non-null   int64
#  8   Work_Life_Balance_Rating           5000 non-null   int64
#  9   Stress_Level                       5000 non-null   object
#  10  Mental_Health_Condition            5000 non-null   category
#  11  Access_to_Mental_Health_Resources  5000 non-null   object
#  12  Productivity_Change                5000 non-null   object
#  13  Social_Isolation_Rating            5000 non-null   int64
#  14  Satisfaction_with_Remote_Work      5000 non-null   object
#  15  Company_Support_for_Remote_Work    5000 non-null   int64
#  16  Physical_Activity                  5000 non-null   category
#  17  Sleep_Quality                      5000 non-null   object
#  18  Region                             5000 non-null   object
# dtypes: category(3), int64(7), object(9)
# memory usage: 679.4+ KB

# %%
df_con_nulls = pd.read_csv('Remote_Work_and_Mental_Health.csv', index_col=0)
df['Mental_Health_Condition'] = df['Mental_Health_Condition'].astype('category')
df['Physical_Activity'] = df['Physical_Activity'].astype('category')
df['Industry'] = df['Industry'].astype('category')

# %%
Data_muestra_con_nulls = df_con_nulls.iloc[1000:2000]
#Data_muestra_con_nulls

# %%
frecuencia = Data_muestra['Mental_Health_Condition'].value_counts()
plt.figure(figsize=(6,4))
colores = ['g', 'y', 'r', 'b']
plt.bar(frecuencia.index, frecuencia.values, color=colores)
plt.title('Cantidad de personas por condición de salud mental')
plt.xlabel('Condición de Salud Mental')
plt.ylabel('Cantidad de Personas')

plt.show()

# %%
plt.figure(figsize=(8,3))
bin_width = 10
bin_range = range(10, 100, bin_width)
sns.histplot(data=df_con_nulls, x='Age', hue="Mental_Health_Condition", multiple="stack", bins=bin_range)
plt.title('Condición Mental según Edades')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')

plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(Data_muestra.Age, Data_muestra.Hours_Worked_Per_Week, alpha=0.3, color='r')
ax.set_title('Horas trabajadas según edad')
ax.set_xlabel('Edad')
ax.set_ylabel('Horas trabajadas a la semana')
# Out:
# Text(0, 0.5, 'Horas trabajadas a la semana')

# %%
plt.figure(figsize=(5,3))
sns.boxplot(data=df, x='Mental_Health_Condition', y='Hours_Worked_Per_Week', color='b')

plt.title('Boxplot de Condiciones Mentales y Horas Trabajadas')
plt.xlabel('Condición Mental')
plt.ylabel('Horas trabajadas a la semana')
plt.xticks(rotation=0)
plt.show()

# %%
sns.displot(data=Data_muestra_con_nulls, x="Hours_Worked_Per_Week", hue="Mental_Health_Condition", multiple="stack", kind="kde")
plt.title('Condición Mental según Edades')
plt.xlabel('Edad')
plt.ylabel('Densidad')
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.boxplot(data=Data_muestra, x='Mental_Health_Condition', y='Age', color='r')

plt.title('Boxplot de Condiciones Mentales y Edad')
plt.xlabel('Condición Mental')
plt.ylabel('Edad de las Personas')
plt.xticks(rotation=0)
plt.show()

# %%
# establecer los límites y bines para el histograma
bin_width = 1
bin_range = range(0, 8, bin_width)

# crear un histograma del nivel de quilibrio entre la vida personal y el trabajo
sns.displot(data=Data_muestra, x="Work_Life_Balance_Rating", hue="Mental_Health_Condition", col="Mental_Health_Condition", bins=bin_range)

# %%
# establecer los límites y bines para el histograma
bin_width = 1
bin_range = range(0, 8, bin_width)

# crear un histograma del nivel de quilibrio entre la vida personal y el trabajo
sns.displot(data=Data_muestra, x="Social_Isolation_Rating", hue="Mental_Health_Condition", col="Mental_Health_Condition", bins=bin_range)
